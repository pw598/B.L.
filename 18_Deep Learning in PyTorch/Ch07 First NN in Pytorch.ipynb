# %%
import numpy as np
import torch

# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('pima-indians-diabetes.csv', delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('pima-indians-diabetes.csv', delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# define the model
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()
)
print(model)

# train the model
loss_fn   = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')

# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )
# Finished epoch 0, latest loss 0.6405858993530273
# Finished epoch 1, latest loss 0.5455929636955261
# Finished epoch 2, latest loss 0.5076649785041809
# Finished epoch 3, latest loss 0.4912090003490448
# Finished epoch 4, latest loss 0.47994235157966614
# Finished epoch 5, latest loss 0.48333877325057983
# Finished epoch 6, latest loss 0.46421682834625244
# Finished epoch 7, latest loss 0.4604715406894684
# Finished epoch 8, latest loss 0.45776689052581787
# Finished epoch 9, latest loss 0.4562927782535553
# Finished epoch 10, latest loss 0.45522037148475647
# Finished epoch 11, latest loss 0.45624658465385437
# Finished epoch 12, latest loss 0.45785272121429443
# Finished epoch 13, latest loss 0.46233701705932617
# Finished epoch 14, latest loss 0.46198418736457825
# Finished epoch 15, latest loss 0.4620119631290436
# Finished epoch 16, latest loss 0.46066221594810486
# Finished epoch 17, latest loss 0.4652239680290222
# Finished epoch 18, latest loss 0.4714861810207367
# Finished epoch 19, latest loss 0.4756476581096649
# Finished epoch 20, latest loss 0.4745481312274933
# Finished epoch 21, latest loss 0.4720819890499115
# Finished epoch 22, latest loss 0.473283052444458
# Finished epoch 23, latest loss 0.473796010017395
# Finished epoch 24, latest loss 0.4727722406387329
# Finished epoch 25, latest loss 0.4742982089519501
# Finished epoch 26, latest loss 0.4748239517211914
# Finished epoch 27, latest loss 0.47583305835723877
# Finished epoch 28, latest loss 0.4749780595302582
# Finished epoch 29, latest loss 0.4758789539337158
# Finished epoch 30, latest loss 0.48194992542266846
# Finished epoch 31, latest loss 0.4845438301563263
# Finished epoch 32, latest loss 0.4845685362815857
# Finished epoch 33, latest loss 0.48567381501197815
# Finished epoch 34, latest loss 0.48873645067214966
# Finished epoch 35, latest loss 0.49023228883743286
# Finished epoch 36, latest loss 0.49019595980644226
# Finished epoch 37, latest loss 0.49112668633461
# Finished epoch 38, latest loss 0.4938133955001831
# Finished epoch 39, latest loss 0.49740466475486755
# Finished epoch 40, latest loss 0.4994370937347412
# Finished epoch 41, latest loss 0.5024433732032776
# Finished epoch 42, latest loss 0.49618566036224365
# Finished epoch 43, latest loss 0.5005010366439819
# Finished epoch 44, latest loss 0.5005743503570557
# Finished epoch 45, latest loss 0.5032476186752319
# Finished epoch 46, latest loss 0.5076051950454712
# Finished epoch 47, latest loss 0.505045473575592
# Finished epoch 48, latest loss 0.506773054599762
# Finished epoch 49, latest loss 0.5053141713142395
# Finished epoch 50, latest loss 0.5051507949829102
# Finished epoch 51, latest loss 0.5027909278869629
# Finished epoch 52, latest loss 0.5027004480361938
# Finished epoch 53, latest loss 0.50254225730896
# Finished epoch 54, latest loss 0.5025579929351807
# Finished epoch 55, latest loss 0.5020963549613953
# Finished epoch 56, latest loss 0.5005933046340942
# Finished epoch 57, latest loss 0.5002908706665039
# Finished epoch 58, latest loss 0.49888917803764343
# Finished epoch 59, latest loss 0.4955753684043884
# Finished epoch 60, latest loss 0.5004177093505859
# Finished epoch 61, latest loss 0.4980977773666382
# Finished epoch 62, latest loss 0.4943360388278961
# Finished epoch 63, latest loss 0.49478623270988464
# Finished epoch 64, latest loss 0.49521225690841675
# Finished epoch 65, latest loss 0.49130380153656006
# Finished epoch 66, latest loss 0.49114280939102173
# Finished epoch 67, latest loss 0.4902315139770508
# Finished epoch 68, latest loss 0.49131831526756287
# Finished epoch 69, latest loss 0.4857565462589264
# Finished epoch 70, latest loss 0.4845288395881653
# Finished epoch 71, latest loss 0.4811088442802429
# Finished epoch 72, latest loss 0.47576653957366943
# Finished epoch 73, latest loss 0.4743330478668213
# Finished epoch 74, latest loss 0.474124550819397
# Finished epoch 75, latest loss 0.4724991023540497
# Finished epoch 76, latest loss 0.4708726704120636
# Finished epoch 77, latest loss 0.4686278700828552
# Finished epoch 78, latest loss 0.470277339220047
# Finished epoch 79, latest loss 0.47025570273399353
# Finished epoch 80, latest loss 0.46806153655052185
# Finished epoch 81, latest loss 0.46515482664108276
# Finished epoch 82, latest loss 0.46509039402008057
# Finished epoch 83, latest loss 0.46375563740730286
# Finished epoch 84, latest loss 0.46694955229759216
# Finished epoch 85, latest loss 0.4629317820072174
# Finished epoch 86, latest loss 0.45854535698890686
# Finished epoch 87, latest loss 0.4634992480278015
# Finished epoch 88, latest loss 0.45658913254737854
# Finished epoch 89, latest loss 0.4579266309738159
# Finished epoch 90, latest loss 0.45436951518058777
# Finished epoch 91, latest loss 0.4539329409599304
# Finished epoch 92, latest loss 0.4524649977684021
# Finished epoch 93, latest loss 0.45333561301231384
# Finished epoch 94, latest loss 0.4478803277015686
# Finished epoch 95, latest loss 0.45095810294151306
# Finished epoch 96, latest loss 0.44534939527511597
# Finished epoch 97, latest loss 0.447373628616333
# Finished epoch 98, latest loss 0.4411683678627014
# Finished epoch 99, latest loss 0.4374924302101135
# Accuracy 0.7838541865348816

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('pima-indians-diabetes.csv', delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# define the model
class PimaClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(8, 12)
        self.act1 = nn.ReLU()
        self.hidden2 = nn.Linear(12, 8)
        self.act2 = nn.ReLU()
        self.output = nn.Linear(8, 1)
        self.act_output = nn.Sigmoid()

    def forward(self, x):
        x = self.act1(self.hidden1(x))
        x = self.act2(self.hidden2(x))
        x = self.act_output(self.output(x))
        return x

model = PimaClassifier()
print(model)

# train the model
loss_fn   = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# compute accuracy
y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")

# make class predictions with the model
predictions = (model(X) > 0.5).int()
for i in range(5):
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# PimaClassifier(
#   (hidden1): Linear(in_features=8, out_features=12, bias=True)
#   (act1): ReLU()
#   (hidden2): Linear(in_features=12, out_features=8, bias=True)
#   (act2): ReLU()
#   (output): Linear(in_features=8, out_features=1, bias=True)
#   (act_output): Sigmoid()
# )
# Accuracy 0.7708333134651184
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.599998474121094, 0.6269999742507935, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.600000381469727, 0.35100001096725464, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.299999237060547, 0.671999990940094, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.100000381469727, 0.16699999570846558, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.099998474121094, 2.2880001068115234, 33.0] => 1 (expected 1)
